# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

print('Pandas version :', pd.__version__)
print('Numpy version  :', np.__version__)
print('Matplot version:', matplotlib.__version__);
print('Seaborn version:', sns.__version__)
print('Sklearn version:', sk.__version__)

print('--------------')
print(pd.Timestamp.now())
# Out:
# Pandas version : 2.2.2
# Numpy version  : 1.26.4
# Matplot version: 3.9.2
# Seaborn version: 0.13.2
# Sklearn version: 1.5.1
# --------------
# 2025-02-14 09:47:01.733829

# %%
df = pd.read_csv('../Data/DifferentScales.csv')
df.head()
# Out:
#           x1          x2          x3
# 0  12.223228  242.582037  397.498452
# 1   5.358685  111.940195  295.508581
# 2   4.823637   12.153608  313.301273
# 3  11.550498  242.262249  444.890520
# 4   6.241505   70.414646  588.852536

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      250 non-null    float64
#  1   x2      250 non-null    float64
#  2   x3      250 non-null    float64
# dtypes: float64(3)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#                x1          x2          x3
# count  250.000000  250.000000  250.000000
# mean     7.979161  130.472878  332.723652
# std      4.408618   78.417952  176.389894
# min      0.016618    0.531485    0.755129
# 25%      4.144341   56.680559  190.864890
# 50%      8.510758  125.766483  331.850339
# 75%     11.927241  198.333826  479.611486
# max     14.943139  258.987317  649.810064

# %%
df.plot()
# Out:
# <Axes: >
